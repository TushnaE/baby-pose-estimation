# %% [markdown]
# # Human Pose Estimation For Early Cerebral Palsy Detection

# %% [markdown]
# ## Introduction:
# (1) OpenPose: Real-time multi-person keypoint detection library for body, face, hands, and foot estimation
#
# paper: https://arxiv.org/pdf/1812.08008.pdf
#
# training set: CMU panoptic dataset (http://domedb.perception.cs.cmu.edu/)
#
# https://github.com/Hzzone/pytorch-openpose
# https://github.com/CMU-Perceptual-Computing-Lab/openpose
#
#
# (2) AlphaPose
#
# https://github.com/MVIG-SJTU/AlphaPose

# %% [markdown]
# ## [1] Pulling Data From AWS S3 Bucket

# %% [markdown]
# #### Boto3 setup

# %%
## allows us to access aws resources and services w/o using gui (low level access)
# !pip install boto3

import boto3

! aws configure list

# %%
client = boto3.client('s3')
response = client.list_buckets()

# %% [markdown]
# #### Downloading S3 files

# %%
s3 = boto3.resource('s3')

# %%
all_buckets = list(s3.buckets.all())

# %%
bucket = s3.Bucket('leeds_dataset')

# %%
! ls ../s3_data

# %%
def download_from_S3(station_date, instance):
    prefix = station_date
#     print("prefix: " + prefix)

    ## get all folders within 'path'
    path = station_date + instance
    print("path: " + path)
    
    response = client.list_objects_v2(
            Bucket='leeds_dataset',
            Prefix ="2021-06-23/leeds_dataset/instance_1624468290044")
    
    return response

# %%
import boto3
from collections import namedtuple
from operator import attrgetter
from botocore.exceptions import ProfileNotFound, ClientError
import os


# S3Obj = namedtuple('S3Obj', ['key', 'mtime', 'size', 'ETag'])
def s3_ls(bucket, path, recursive=False, list_dirs=True, list_objs=True):
    """
    Iterator that lists a bucket's objects under path, (optionally) starting with
    start and ending before end.

    If recursive is False, then list only the "depth=0" items (dirs and objects).

    If recursive is True, then list recursively all objects (no dirs).

    Args:
        bucket:
            a boto3.resource('s3').Bucket().
        path:
            a directory in the bucket.
        recursive:
            optional, default True. If True, lists only objects. If False, lists
            only depth 0 "directories" and objects.
        list_dirs:
            optional, default True. Has no effect in recursive listing. On
            non-recursive listing, if False, then directories are omitted.
        list_objs:
            optional, default True. If False, then directories are omitted.

    Returns:
        an iterator of S3Obj.
"""
    kwargs = dict()
    kwargs.update(Delimiter='/')
#     if not path.endswith('/'):
#         path += '/'
    
    if not recursive:
        kwargs.update(Delimiter='/')
        if not path.endswith('/'):
            path += '/'
    
    kwargs.update(Prefix=path)
    paginator = bucket.meta.client.get_paginator('list_objects')
    for resp in paginator.paginate(Bucket=bucket.name, **kwargs):
        q = []
        if 'CommonPrefixes' in resp and list_dirs:
            q = [S3Obj(f['Prefix'], None, None, None) for f in resp['CommonPrefixes']]
        if 'Contents' in resp and list_objs:
            q += [S3Obj(f['Key'], f['LastModified'], f['Size'], f['ETag']) for f in resp['Contents']]
        # note: even with sorted lists, it is faster to sort(a+b)
        # than heapq.merge(a, b) at least up to 10K elements in each list
        q = sorted(q, key=attrgetter('key'))
        for p in q:
            yield p


def __prev_str(s):
    if len(s) == 0:
        return s
    s, c = s[:-1], ord(s[-1])
    if c > 0:
        s += chr(c - 1)
    s += ''.join(['\u7FFF' for _ in range(10)])
    return s

# %%
# # iterate through all S3 objects under some dir
# S3Obj = namedtuple('S3Obj', ['key', 'mtime', 'size', 'ETag'])


# path = "leeds_dataset"
# dir_content = list(s3_ls(bucket, path))

# # dir_content[0]
# for item in dir_content:
#     item_key = item.key
#     split = item_key.split("/")[:5]
#     if "session" not in split[4]:
#         continue
# #         print(item)
    
# #     print(item_key)
#     session_path = list(s3_ls(bucket, item_key))
    
#     for scene in session_path:
# #         print(scene.key)
#         split_session = scene.key.split("/")[5:]
#         if "induct" not in split_session[0]:
#             continue
        
#         image_key = scene.key+path_end.strip()
#         final_dir = scene.key.split("/")
#         scene_num = final_dir[-2].strip()

#         ## unique frame identifier
#         #                     print(scene_num)

#         ## get image w/ this key
#         #                     print(image_key)

#         ## place image here + unique scene id
#         print(final_dir)

#         if not os.path.exists(os.path.dirname(final_dir)):
#             os.makedirs(os.path.dirname(final_dir))


#         try:
#             client.download_file('leeds_dataset', image_key, final_dir)
#             print("found!")
#         except ClientError as e:
#             if e.response['Error']['Code'] == "404":
#                 print("The object does not exist.")
#             else:
#                 raise

# %% [markdown]
# ## [2] Evaluating OpenPose Model on Leeds Dataset

# %%
### Running models in the first place

MPII Human Pose Dataset

LSP Dataset: Leeds Sports Pose
    
    leeds_sports_trials
    
    
## More videos


# test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/distance_estimation/subject_leg.jpg'
# oriImg = cv2.imread(test_image)

# %%
import cv2
import matplotlib.pyplot as plt
import copy
import numpy as np
import glob

from src import model
from src import util
from src.body import Body

# %%
body_estimation = Body('model/body_pose_model.pth')

# test_image = 'images/distance_estimation/subject_leg.jpg'
# test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/demo.jpg'


test_images = glob.glob("/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/leeds_sports_trials/*.jpg")

len(test_images)
# Out:
# 124

# %%
finished_images = glob.glob("/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/leeds_sports_finished/*.jpg")

# len(finished_images)

remaining_images = []

for im in test_images:
    num = im.split("/")[-1]   
    
    if num=="im0114.jpg" or num=="im0048.jpg" or num=="im0101.jpg" or num=="im0111.jpg" or num=="im0041.jpg" or num=="im0167.jpg":
        continue
    if num=="im0065.jpg" or num=="im0070.jpg" or num=="im0015.jpg" or num=="im0032.jpg" or num=="im0097.jpg":
        continue
        
    complete_path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/leeds_sports_finished/" + num
    
    if complete_path in finished_images:
        continue
    else:
        remaining_images.append(im)
        
print(len(remaining_images))
# Out:
# 9

# %%
for test_image in remaining_images:
    im_name = test_image.split("/")[-1]
    print(im_name)
    
    oriImg = cv2.imread(test_image)  # B,G,R order
    print(type(oriImg))
    canvas = copy.deepcopy(oriImg)
    candidate, subset = body_estimation(oriImg)
    print(type(canvas))
    aList, canvas = util.draw_bodypose(canvas, candidate, subset)
    print(type(canvas))
    
    
    plt.imsave("/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/leeds_sports_finished/" + im_name, canvas[:, :, [2, 1, 0]])
# Out:
# im0159.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0165.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0164.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0170.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0158.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0169.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0168.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0156.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# im0157.jpg
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
finished_images = glob.glob("/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/leeds_sports_finished/*.jpg")
len(finished_images)
# Out:
# 104

# %% [markdown]
# ## [3] Evaluating AlphaPose Model on Leeds Dataset

# %%
## Code in Google Colab (had to run this on GPU)

# %%
cfg_file = "/Users/tushna/Desktop/Classes/Projects/AlphaPose-master/configs/coco/resnet/256x192_res50_lr1e-3_1x-simple.yaml"

trained_model = "/Users/tushna/Desktop/Classes/Projects/AlphaPose-master/pretrained_models/simple_res50_256x192.pth"

img_source_directory = "/Users/tushna/Desktop/alpha_images"

img_dest_directory = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/lsp_dataset/alphapose_outputs/"

# %% [markdown]
# ## [4] Tracking Pose Over Time --> Video!

# %%
video datasets: http://domedb.perception.cs.cmu.edu/dataset.html
        
## first, this was a perception problem
## then, it became an object tracking problem


# so i tried a selection of object tracking approaches: optical flow, etc
# and decided to do XX centroid tracking algorithm
# using centroid tracking i was able to tell when the kick was making the leg go up and when it was making
# the leg go down

## show a sample demo video of the output on the baby video
## then, do the other metrics (now that we know kick up and kick down)

# %% [markdown]
# #### Video to process

# %%
from IPython.display import Video

Video("images/strokegait_clipped.mp4")
# Out:
# <video src="images/strokegait_clipped.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Splitting video into frames with FFMPEG

# %%
## We need to track over time (video), but my models only can process singular frames
## Using FFMPEG to split up videos into frames

# %%
! ffmpeg -i movtoavi.avi -vf strokegait_allframes/frame%d.png

# %% [markdown]
# #### Evaluating ideal FPS

# %%
# ffmpeg can be used to change the frame rate of an existing video, such that the output frame rate is lower or higher than the input frame

# through trial and error, I noticed that the best was 10fps

# %%
! ffmpeg -i movtoavi.avi -vf "fps=10" strokegait_10FPS/frame%04d.png

# %% [markdown]
# #### Processing the frames

# %%
import cv2
import matplotlib.pyplot as plt
import copy
import numpy as np

from src import model
from src import util
from src.body import Body

# %%
body_estimation = Body('model/body_pose_model.pth')

ankles_across_frames = []


## put a loop here to calculate which frame you're on
for i in range(1,61):

    filename = "images/strokegait_10FPS/frame"+str(i)+".png"

    test_image = filename
    oriImg = cv2.imread(test_image)  # B,G,R order
    candidate, subset = body_estimation(oriImg)
    canvas = copy.deepcopy(oriImg)
    ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

    ## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively


    ankles_across_frames.append(ankles)

    # left_ankle = ankles[0]      ## tuple 0
    # right_ankle = ankles[1]      ## tuple 1
    

    path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/strokegait_10FPS_processed/"
    plt.imshow(canvas[:, :, [2, 1, 0]])
    plt.axis('off')
    plt.savefig(path + "frame"+str(i)+".png")
    
    # plt.show()

# %% [markdown]
# #### Converting processed frames back into video for visualization over time

# %%
# ! ffmpeg -r 10 -f image2 -i images/strokegait_10FPS_processed/frame%d.png -vcodec libx264 -crf 15  -pix_fmt yuv420p /Users/tushna/Desktop/test.mp4
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
Video("images/gait_processed_video.mp4")
# Out:
# <video src="images/gait_processed_video.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## [5] Isolating Ankle Movement Over Time

# %% [markdown]
# #### Processing the frames

# %%
body_estimation = Body('model/body_pose_model.pth')

ankles_across_frames = []

for i in range(1,61):

    filename = "images/strokegait_10FPS/frame"+str(i)+".png"

    test_image = filename
    oriImg = cv2.imread(test_image)  # B,G,R order
    candidate, subset = body_estimation(oriImg)
    canvas = copy.deepcopy(oriImg)
    ankles, canvas = util.draw_bodypose(canvas, candidate, subset)


    ankles_across_frames.append(ankles)

    left_ankle = ankles[0]      ## tuple 0
    right_ankle = ankles[1]      ## tuple 1
    
    
    path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/strokegait_10FPS_ankles/"
    
    the_im = cv2.imread(test_image)
    plt.imshow(the_im[:, :, [2, 1, 0]])
    
    plt.plot(left_ankle[0], left_ankle[1], 'bo')
    plt.plot(right_ankle[0], right_ankle[1], 'bo')
    
    plt.axis('off')
    plt.savefig(path + "frame"+str(i)+".png")

# %% [markdown]
# #### Calculated ankle coordinates over 60 frames

# %%
print(ankles_across_frames)
# Out:
# [[(237.0, 305.0), (321.0, 309.0)], [(237.0, 305.0), (321.0, 309.0)], [(237.0, 305.0), (321.0, 309.0)], [(226.0, 300.0), (307.0, 311.0)], [(225.0, 291.0), (297.0, 311.0)], [(236.0, 278.0), (282.0, 311.0)], [(254.0, 280.0), (272.0, 309.0)], [(292.0, 301.0), (255.0, 309.0)], [(318.0, 306.0), (244.0, 310.0)], [(321.0, 306.0), (230.0, 306.0)], [(312.0, 307.0), (221.0, 304.0)], [(298.0, 305.0), (225.0, 290.0)], [(287.0, 306.0), (239.0, 285.0)], [(269.0, 295.0), (271.0, 296.0)], [(297.0, 306.0), (261.0, 306.0)], [(246.0, 305.0), (324.0, 307.0)], [(238.0, 305.0), (320.0, 310.0)], [(226.0, 299.0), (306.0, 310.0)], [(229.0, 287.0), (296.0, 311.0)], [(243.0, 278.0), (280.0, 309.0)], [(257.0, 282.0), (272.0, 308.0)], [(298.0, 302.0), (255.0, 309.0)], [(320.0, 305.0), (244.0, 308.0)], [(319.0, 307.0), (229.0, 305.0)], [(309.0, 306.0), (222.0, 302.0)], [(294.0, 305.0), (226.0, 288.0)], [(285.0, 306.0), (242.0, 283.0)], [(269.0, 300.0), (275.0, 297.0)], [(259.0, 305.0), (303.0, 307.0)], [(243.0, 30
# ...

# %% [markdown]
# #### [left_ankle, right_ankle], where each ankle has (x,y)

# %%
## Each item in the list of ankles_across_frames is a set of [left_ankle, right_ankle] in frame[i]
## the left_ankle and right_ankle are each tuples representing (x,y) coordinates


print(len(ankles_across_frames[0]))
# Out:
# 2

# %%
for i in range(1,61):

    filename = "images/strokegait_10FPS/frame"+str(i)+".png"

    test_image = filename
    oriImg = cv2.imread(test_image)  # B,G,R order


    #     candidate, subset = body_estimation(oriImg)
    #     canvas = copy.deepcopy(oriImg)
    #     ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

    ## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively


    #     ankles_across_frames.append(ankles)

    ankles = ankles_across_frames[i-1]
    print(ankles)

    left_ankle = ankles[0]      ## tuple 0
    right_ankle = ankles[1]      ## tuple 1

    print(left_ankle)
    print(right_ankle)


    #     canvas = copy.deepcopy(oriImg)

    path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/strokegait_10FPS_ankles/"

    the_im = cv2.imread(test_image)
    plt.imshow(the_im[:, :, [2, 1, 0]])

    plt.plot(left_ankle[0], left_ankle[1], 'bo')
    plt.plot(right_ankle[0], right_ankle[1], 'bo')

    plt.axis('off')
    plt.savefig(path + "frame"+str(i)+".png")

        # plt.show()

# %% [markdown]
# #### Converting processed frames back into video for visualization over time

# %%
# ! ffmpeg -r 10 -f image2 -i images/strokegait_10FPS_ankles/frame%d.png -vcodec libx264 -crf 15  -pix_fmt yuv420p /Users/tushna/Desktop/ankles_only.mp4
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
Video("images/ankles_only.mp4")
# Out:
# <video src="images/ankles_only.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## [6] Applying HPE to Baby Pose Estimation

# %% [markdown]
# #### Beginning with baby images

# %%
import cv2
import matplotlib.pyplot as plt
import copy
import numpy as np

from src import model
from src import util
from src.body import Body

body_estimation = Body('model/body_pose_model.pth')

# test_image = 'images/distance_estimation/subject_leg.jpg'

test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/demo.jpg'

oriImg = cv2.imread(test_image)  # B,G,R order

print(type(oriImg))
# Out:
# <class 'numpy.ndarray'>

# %%
canvas = copy.deepcopy(oriImg)
candidate, subset = body_estimation(oriImg)

print(type(canvas))
# Out:
# <class 'numpy.ndarray'>

# %%
aList, canvas = util.draw_bodypose(canvas, candidate, subset)
print(type(canvas))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(canvas[:, :, [2, 1, 0]])
# plt.imshow(canvas)

# plt.imshow(canvas[:,:,[2,1,0]])
plt.axis('off')
plt.show()

# %%
test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/demo2.jpg'

oriImg = cv2.imread(test_image)  # B,G,R order

canvas = copy.deepcopy(oriImg)
candidate, subset = body_estimation(oriImg)

aList, canvas = util.draw_bodypose(canvas, candidate, subset)

plt.imshow(canvas[:, :, [2, 1, 0]])
plt.axis('off')
plt.show()

# %%
test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/demo3.jpeg'

oriImg = cv2.imread(test_image)  # B,G,R order

canvas = copy.deepcopy(oriImg)
candidate, subset = body_estimation(oriImg)

aList, canvas = util.draw_bodypose(canvas, candidate, subset)

plt.imshow(canvas[:, :, [2, 1, 0]])
plt.axis('off')
plt.show()

# %%
test_image = '/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/demo4.jpeg'

oriImg = cv2.imread(test_image)  # B,G,R order

canvas = copy.deepcopy(oriImg)
candidate, subset = body_estimation(oriImg)

aList, canvas = util.draw_bodypose(canvas, candidate, subset)

plt.imshow(canvas[:, :, [2, 1, 0]])
plt.axis('off')
plt.show()

# %% [markdown]
# ## [7] Tracking Baby Pose Over Time

# %% [markdown]
# #### Converting numerous videos to frames to prep for processing

# %%
## discuss ethicality of baby videos
## http://domedb.perception.cs.cmu.edu/toddler.html -> videos

# %% [markdown]
# #### two_month_atypical baby video

# %%
# time for i in {0..39} ; do ffmpeg -accurate_seek -ss `echo $i*60.0 | bc` -i input.mp4   -frames:v 1 period_down_$i.bmp ; done

vid = "/images/baby_videos/two_month_atypical.mp4"

! ffmpeg -i images/baby_videos/two_month_atypical.mp4 -vf fps=10 images/baby_videos/two_month_atypical/%d.jpg
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %% [markdown]
# #### baby_walking video

# %%
vid = "/images/baby_videos/baby_walking.mp4"

! ffmpeg -r 10 -i images/baby_videos/baby_walking.mp4 -vf fps=10 images/baby_videos/baby_walking/%d.jpg
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %% [markdown]
# #### six_month_atypical baby video

# %%
! ffmpeg -r 1 -i images/baby_videos/six_month_atypical.mp4 -vf fps=1 images/baby_videos/six_month_atypical_redo/%d.jpg
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %% [markdown]
# #### newborn_kicking baby video

# %%
! ffmpeg -r 2 -i images/baby_videos/newborn_kicking.mp4 -vf fps=2 images/baby_videos/newborn_kicking/%d.jpg
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %% [markdown]
# ### Tracking Ankles in 'Baby Walking' Video

# %%
## First we have to order to frames

baby_walking_images = glob.glob("images/baby_videos/baby_walking/scene1/*.jpg")
len(baby_walking_images)

baby_walking_images.sort()
# print(baby_walking_images)

# %%
os/baby_walking/scene1/938.jpg', 'images/baby_videos/baby_walking/scene1/939.jpg', 'images/baby_videos/baby_walking/scene1/941.jpg', 'images/baby_videos/baby_walking/scene1/943.jpg', 'images/baby_videos/baby_walking/scene1/944.jpg', 'images/baby_videos/baby_walking/scene1/949.jpg', 'images/baby_videos/baby_walking/scene1/950.jpg', 'images/baby_videos/baby_walking/scene1/951.jpg', 'images/baby_videos/baby_walking/scene1/953.jpg', 'images/baby_videos/baby_walking/scene1/956.jpg', 'images/baby_videos/baby_walking/scene1/959.jpg', 'images/baby_videos/baby_walking/scene1/961.jpg', 'images/baby_videos/baby_walking/scene1/962.jpg', 'images/baby_videos/baby_walking/scene1/965.jpg', 'images/baby_videos/baby_walking/scene1/967.jpg', 'images/baby_videos/baby_walking/scene1/969.jpg', 'images/baby_videos/baby_walking/scene1/971.jpg', 'images/baby_videos/baby_walking/scene1/974.jpg', 'images/baby_videos/baby_walking/scene1/975.jpg', 'images/baby_videos/baby_walking/scene1/977.jpg', 'images/baby_videos/baby_walking/scene1/980.jpg', 'images/baby_videos/baby_walking/scene1/983.jpg', 'images/baby_videos/baby_walking/scene1/985.jpg', 'images/baby_videos/baby_walking/scene1/986.jpg', 'images/baby_videos/baby_walking/scene1/987.jpg', 'images/baby_videos/baby_walking/scene1/992.jpg', 'images/baby_videos/baby_walking/scene1/993.jpg', 'images/baby_videos/baby_walking/scene1/995.jpg', 'images/baby_videos/baby_walking/scene1/997.jpg', 'images/baby_videos/baby_walking/scene1/998.jpg']

ordered_list.append(['images/baby_videos/baby_walking/scene1/1003.jpg', 'images/baby_videos/baby_walking/scene1/1004.jpg', 'images/baby_videos/baby_walking/scene1/1005.jpg', 'images/baby_videos/baby_walking/scene1/1007.jpg', 'images/baby_videos/baby_walking/scene1/1010.jpg', 'images/baby_videos/baby_walking/scene1/1013.jpg', 'images/baby_videos/baby_walking/scene1/1015.jpg', 'images/baby_videos/baby_walking/scene1/1016.jpg', 'images/baby_videos/baby_walking/scene1/1019.jpg', 'images/baby_videos/baby_walking/scene1/1021.jpg', 'images/baby_videos/baby_walking/scene1/1023.jpg'])

# print(ordered_list)

# %%
body_estimation = Body('model/body_pose_model.pth')

# ankles_across_frames = []

## put a loop here to calculate which frame you're on
# for filename in ordered_list:

filename = 'images/baby_videos/baby_walking/scene1/681.jpg'

num = filename.split("/")[-1]

#     if num == "465.jpg":
#         continue

print(filename)

#     filename = "images/strokegait_10FPS/frame"+str(i)+".png"

test_image = filename
oriImg = cv2.imread(test_image)  # B,G,R order

print(oriImg.shape)

candidate, subset = body_estimation(oriImg)
canvas = copy.deepcopy(oriImg)
ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

print(ankles)

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively

print(ankles)

ankles_across_frames.append(ankles)

left_ankle = ankles[0]      ## tuple 0
right_ankle = ankles[1]      ## tuple 1


#     canvas = copy.deepcopy(oriImg)

path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/baby_videos/baby_walking/scene1_processed/" + num 

the_im = cv2.imread(test_image)
plt.imshow(the_im[:, :, [2, 1, 0]])

plt.plot(left_ankle[0], left_ankle[1], 'bo')
plt.plot(right_ankle[0], right_ankle[1], 'bo')

plt.axis('off')
plt.savefig(path)

# plt.show()
# Out:
# images/baby_videos/baby_walking/scene1/681.jpg
# (360, 640, 3)
# [(377.0, 292.0), (319.0, 287.0)]
# [(377.0, 292.0), (319.0, 287.0)]

# %%
## Converting it into a video for visualization over time

! ffmpeg -r 10 -f image2 -i images/baby_videos/baby_walking/scene1_processed/%d.jpg -vcodec libx264 -crf 0  -pix_fmt yuv420p /Users/tushna/Desktop/baby_walking_processed.mp4
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
from IPython.display import Video

Video("images/baby_videos/baby_walking_processed.mp4")
# Out:
# <video src="images/baby_videos/baby_walking_processed.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Tracking Ankles in 'Baby Laying Down' Video
#
# Understanding ankle movements on babies lying down, kicking upwards

# %%
body_estimation = Body('model/body_pose_model.pth')

ankles_across_frames = []

## put a loop here to calculate which frame you're on
# for filename in ordered_list:

filename = 'images/baby_videos/newborn_laying/scene1/97.jpg'

num = filename.split("/")[-1]

#     if num == "465.jpg":
#         continue

print(filename)

#     filename = "images/strokegait_10FPS/frame"+str(i)+".png"

test_image = filename
oriImg = cv2.imread(test_image)  # B,G,R order

## np.rot90(m)


print(oriImg.shape)

candidate, subset = body_estimation(oriImg)
canvas = copy.deepcopy(oriImg)
ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

print(ankles)

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively

print(ankles)

ankles_across_frames.append(ankles)

left_ankle = ankles[0]      ## tuple 0
right_ankle = ankles[1]      ## tuple 1


#     canvas = copy.deepcopy(oriImg)

path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/baby_videos/newborn_laying/scene1_processed/" + num 

the_im = cv2.imread(test_image)
plt.imshow(the_im[:, :, [2, 1, 0]])

plt.plot(left_ankle[0], left_ankle[1], 'bo')
plt.plot(right_ankle[0], right_ankle[1], 'bo')

plt.axis('off')
plt.savefig(path)

# plt.show()
# Out:
# images/baby_videos/newborn_laying/scene1/97.jpg
# (360, 640, 3)
# [(427.0, 171.0), (121.0, 190.0)]
# [(427.0, 171.0), (121.0, 190.0)]

# %%
body_estimation = Body('model/body_pose_model.pth')

ankles_across_frames = []

## put a loop here to calculate which frame you're on
# for filename in ordered_list:

filename = 'images/baby_videos/newborn_laying/scene1/1393.jpg'

num = filename.split("/")[-1]

#     if num == "465.jpg":
#         continue

print(filename)

#     filename = "images/strokegait_10FPS/frame"+str(i)+".png"

test_image = filename
oriImg = cv2.imread(test_image)  # B,G,R order

oriImg = cv2.rotate(oriImg, cv2.ROTATE_90_COUNTERCLOCKWISE)

## np.rot90(m)


print(oriImg.shape)

candidate, subset = body_estimation(oriImg)
canvas = copy.deepcopy(oriImg)
ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

print(ankles)

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively

print(ankles)

ankles_across_frames.append(ankles)

left_ankle = ankles[0]      ## tuple 0
right_ankle = ankles[1]      ## tuple 1


#     canvas = copy.deepcopy(oriImg)

path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/baby_videos/newborn_laying/scene1_processed/" + num 

the_im = cv2.imread(test_image)
the_im = cv2.rotate(the_im, cv2.ROTATE_90_COUNTERCLOCKWISE)

plt.imshow(the_im[:, :, [2, 1, 0]])

plt.plot(left_ankle[0], left_ankle[1], 'bo')
plt.plot(right_ankle[0], right_ankle[1], 'bo')

plt.axis('off')
plt.savefig(path)

# plt.show()
# Out:
# images/baby_videos/newborn_laying/scene1/1393.jpg
# (640, 360, 3)
# [(190.0, 204.0), (91.0, 569.0)]
# [(190.0, 204.0), (91.0, 569.0)]

# %% [markdown]
# #### Converting it into a video for visualization over time

# %%
# ! ffmpeg -r 10 -f image2 -i images/baby_videos/newborn_laying/scene1_processed/%d.jpg -vcodec libx264 -crf 0  -pix_fmt yuv420p /Users/tushna/Desktop/newborn_laying_processed.mp4
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
## Point out artifact --> sometimes the small hands being confused for feet...
## the original model was trained on full grown adults, wearing shoes and pants and shirts
## the model, when extending to babies, has trouble because it's used to being able to tell the difference
## between ankles and wrists due to the clothes and other textures in the image

Video("images/baby_videos/newborn_laying_processed.mp4")
# Out:
# <video src="images/baby_videos/newborn_laying_processed.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## [8] Calculating Metrics

# %% [markdown]
# #### Typical Baby Leg Movement

# %%
Video("images/baby_videos/newborn_kicking.mp4")

# observe timestamp [0:54] and onwards
# Out:
# <video src="images/baby_videos/newborn_kicking.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Two Month Old, Atypical Child

# %%
Video("images/baby_videos/two_month_atypical.mp4")

## Very early signs of atypical movement
# observe timestamp [0:45] and onwards
# Out:
# <video src="images/baby_videos/two_month_atypical.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Six Month Old, Atypical Child

# %%
Video("images/baby_videos/six_month_atypical.mp4")

## Very early signs of atypical movement
# observe timestamp [1:10] and onwards
# Out:
# <video src="images/baby_videos/six_month_atypical.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ##  Characteristics of early onset cerebral palsy:

# %% [markdown]
# #### Little to no antigravity movement in the feet
#
# #### Uneven antigravity movement (one leg doesn't move at all, or moves rarely)

# %% [markdown]
# ##  Metrics

# %% [markdown]
# #### Calculate Z-direction of movement (upward motion of each foot) --> taken from side angle, baby in supine
#
# #### Calculate the frequency of kicks (understanding level of motion in the feet)
#
# #### Calculate the distance moved by the left ankle compared with distance moved by right ankle

# %% [markdown]
# ### Calculating *typical* z motion

# %%
## baby in supine position, camera angle from the side

# %%
import glob

imgs = glob.glob("images/baby_metrics/Z-typical/*.jpg")
imgs.sort()
print(imgs)
# Out:
# ['images/baby_metrics/Z-typical/413 copy.jpg', 'images/baby_metrics/Z-typical/415 copy.jpg', 'images/baby_metrics/Z-typical/417 copy.jpg', 'images/baby_metrics/Z-typical/418 copy.jpg', 'images/baby_metrics/Z-typical/420 copy.jpg', 'images/baby_metrics/Z-typical/423 copy.jpg', 'images/baby_metrics/Z-typical/425 copy.jpg', 'images/baby_metrics/Z-typical/427 copy.jpg', 'images/baby_metrics/Z-typical/428 copy.jpg', 'images/baby_metrics/Z-typical/430 copy.jpg', 'images/baby_metrics/Z-typical/433 copy.jpg', 'images/baby_metrics/Z-typical/435 copy.jpg', 'images/baby_metrics/Z-typical/437 copy.jpg', 'images/baby_metrics/Z-typical/438 copy.jpg', 'images/baby_metrics/Z-typical/440 copy.jpg', 'images/baby_metrics/Z-typical/443 copy.jpg', 'images/baby_metrics/Z-typical/445 copy.jpg', 'images/baby_metrics/Z-typical/447 copy.jpg', 'images/baby_metrics/Z-typical/448 copy.jpg', 'images/baby_metrics/Z-typical/450 copy.jpg', 'images/baby_metrics/Z-typical/453 copy.jpg', 'images/baby_metrics/Z-typical/
# ...

# %%
frame_num = 1
ankles_across_frames = []

# %%
body_estimation = Body('model/body_pose_model.pth')



## put a loop here to calculate which frame you're on
# for filename in ordered_list:

filename = 'images/baby_metrics/Z-typical/483 copy.jpg'

# num = filename.split("/")[-1]

#     if num == "465.jpg":
#         continue

print(filename)

#     filename = "images/strokegait_10FPS/frame"+str(i)+".png"

test_image = filename
oriImg = cv2.imread(test_image)  # B,G,R order

oriImg = cv2.rotate(oriImg, cv2.ROTATE_90_COUNTERCLOCKWISE)

## np.rot90(m)


print(oriImg.shape)

candidate, subset = body_estimation(oriImg)
canvas = copy.deepcopy(oriImg)
ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

print(ankles)

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively

print(ankles)

ankles_across_frames.append(ankles)

left_ankle = ankles[0]      ## tuple 0
right_ankle = ankles[1]      ## tuple 1


#     canvas = copy.deepcopy(oriImg)

path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/baby_metrics/Z-typical_processed/" + str(frame_num) + ".jpg" 


the_im = cv2.imread(test_image)
the_im = cv2.rotate(the_im, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(the_im[:, :, [2, 1, 0]])

plt.plot(left_ankle[0], left_ankle[1], 'bo')
plt.plot(right_ankle[0], right_ankle[1], 'bo')

plt.axis('off')
plt.savefig(path)

# plt.show()
# Out:
# images/baby_metrics/Z-typical/483 copy.jpg
# (480, 360, 3)
# [(107.0, 217.0), (145.0, 226.0)]
# [(107.0, 217.0), (145.0, 226.0)]

# %%
frame_num += 1

# %%
typical_ankle_movement = ankles_across_frames
print(typical_ankle_movement)
# Out:
# [[(234.0, 413.0), (224.0, 391.0)], [(234.0, 411.0), (225.0, 395.0)], [(234.0, 414.0), (226.0, 400.0)], [(233.0, 409.0), (226.0, 397.0)], [(230.0, 408.0), (229.0, 401.0)], [(215.0, 410.0), (233.0, 393.0)], [(210.0, 403.0), (231.0, 391.0)], [(197.0, 410.0), (224.0, 392.0)], [(197.0, 398.0), (219.0, 387.0)], [(181.0, 390.0), (223.0, 87.0)], [(157.0, 354.0), (171.0, 350.0)], [(151.0, 330.0), (145.0, 306.0)], [(149.0, 298.0), (132.0, 305.0)], [(152.0, 268.0), (68.0, 227.0)], [(221.0, 87.0), (221.0, 87.0)], [(222.0, 87.0), (222.0, 87.0)], [(222.0, 87.0), (222.0, 87.0)], [(222.0, 85.0), (222.0, 85.0)], [(223.0, 86.0), (223.0, 86.0)], [(224.0, 88.0), (224.0, 88.0)], [(224.0, 87.0), (224.0, 87.0)], [(225.0, 87.0), (225.0, 87.0)], [(225.0, 88.0), (225.0, 88.0)], [(225.0, 88.0), (225.0, 88.0)], [(225.0, 89.0), (225.0, 89.0)], [(225.0, 90.0), (225.0, 90.0)], [(127.0, 235.0), (79.0, 246.0)], [(139.0, 230.0), (28.0, 342.0)], [(224.0, 88.0), (224.0, 88.0)], [(223.0, 89.0), (223.0, 89.0)], [(137.0, 
# ...

# %%
## Converting it into a video for visualization over time

! ffmpeg -r 10 -f image2 -i images/baby_metrics/Z-typical_processed/%d.jpg -vcodec libx264 -crf 0  -pix_fmt yuv420p /Users/tushna/Desktop/z_typical_processed.mp4
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with Apple clang version 11.0.3 (clang-1103.0.32.62)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.3.1 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
# ...

# %%
Video("images/baby_metrics/z_typical_processed.mp4")
# Out:
# <video src="images/baby_metrics/z_typical_processed.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Calculating *atypical* z motion

# %%
## baby in supine position, camera angle from the side

# %%
import glob

imgs = glob.glob("images/baby_metrics/Z-atypical/*.jpg")
imgs.sort()
print(imgs)
# Out:
# ['images/baby_metrics/Z-atypical/1981.jpg', 'images/baby_metrics/Z-atypical/1982.jpg', 'images/baby_metrics/Z-atypical/1983.jpg', 'images/baby_metrics/Z-atypical/1984.jpg', 'images/baby_metrics/Z-atypical/1985.jpg', 'images/baby_metrics/Z-atypical/1986.jpg', 'images/baby_metrics/Z-atypical/1987.jpg', 'images/baby_metrics/Z-atypical/1988.jpg', 'images/baby_metrics/Z-atypical/1989.jpg', 'images/baby_metrics/Z-atypical/1990.jpg', 'images/baby_metrics/Z-atypical/1991.jpg', 'images/baby_metrics/Z-atypical/1992.jpg', 'images/baby_metrics/Z-atypical/1993.jpg', 'images/baby_metrics/Z-atypical/1994.jpg', 'images/baby_metrics/Z-atypical/1995.jpg', 'images/baby_metrics/Z-atypical/1996.jpg', 'images/baby_metrics/Z-atypical/1997.jpg', 'images/baby_metrics/Z-atypical/2001.jpg', 'images/baby_metrics/Z-atypical/2002.jpg', 'images/baby_metrics/Z-atypical/2011.jpg', 'images/baby_metrics/Z-atypical/2012.jpg', 'images/baby_metrics/Z-atypical/2016.jpg', 'images/baby_metrics/Z-atypical/2017.jpg', 'images/
# ...

# %%
frame_num = 1
atypical_ankle_movement = []

# %%
body_estimation = Body('model/body_pose_model.pth')



## put a loop here to calculate which frame you're on
# for filename in ordered_list:

filename = 'images/baby_metrics/Z-atypical/2081.jpg'

# num = filename.split("/")[-1]

#     if num == "465.jpg":
#         continue

print(filename)

#     filename = "images/strokegait_10FPS/frame"+str(i)+".png"

test_image = filename
oriImg = cv2.imread(test_image)  # B,G,R order

oriImg = cv2.rotate(oriImg, cv2.ROTATE_90_COUNTERCLOCKWISE)

## np.rot90(m)


print(oriImg.shape)

candidate, subset = body_estimation(oriImg)
canvas = copy.deepcopy(oriImg)
ankles, canvas = util.draw_bodypose(canvas, candidate, subset)

print(ankles)

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively

print(ankles)

atypical_ankle_movement.append(ankles)

left_ankle = ankles[0]      ## tuple 0
right_ankle = ankles[1]      ## tuple 1


#     canvas = copy.deepcopy(oriImg)

path = "/Users/tushna/Desktop/Classes/Projects/HumanPoseEstimation/pytorch-openpose/images/baby_metrics/Z-atypical_processed/" + str(frame_num) + ".jpg" 


the_im = cv2.imread(test_image)
the_im = cv2.rotate(the_im, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(the_im[:, :, [2, 1, 0]])

plt.plot(left_ankle[0], left_ankle[1], 'bo')
plt.plot(right_ankle[0], right_ankle[1], 'bo')

plt.axis('off')
plt.savefig(path)

# plt.show()
# Out:
# images/baby_metrics/Z-atypical/2081.jpg
# (480, 360, 3)
# [(236.0, 395.0), (202.0, 388.0)]
# [(236.0, 395.0), (202.0, 388.0)]

# %%
frame_num += 1

# %%
print(atypical_ankle_movement)
# Out:
# [[(200.0, 428.0), (197.0, 422.0)], [(198.0, 429.0), (195.0, 422.0)], [(198.0, 429.0), (196.0, 423.0)], [(198.0, 429.0), (196.0, 422.0)], [(199.0, 428.0), (196.0, 421.0)], [(200.0, 427.0), (197.0, 419.0)], [(198.0, 426.0), (197.0, 416.0)], [(197.0, 427.0), (197.0, 419.0)], [(197.0, 427.0), (198.0, 421.0)], [(197.0, 427
Atypical = [[(200.0, 428.0), (197.0, 422.0)], [(198.0, 429.0), (195.0, 422.0)], [(198.0, 429.0), (196.0, 423.0)], [(198.0, 429.0), (196.0, 422.0)], [(199.0, 428.0), (196.0, 421.0)], [(200.0, 427.0), (197.0, 419.0)], [(198.0, 426.0), (197.0, 416.0)], [(197.0, 427.0), (197.0, 419.0)], [(197.0, 427.0), (198.0, 421.0)], [(197.0, 427.0), (198.0, 420.0)], [(256.0, 354.0), (196.0, 422.0)], [(256.0, 359.0), (196.0, 424.0)], [(257.0, 357.0), (196.0, 423.0)], [(256.0, 361.0), (197.0, 423.0)], [(255.0, 363.0), (198.0, 423.0)], [(257.0, 363.0), (197.0, 421.0)], [(200.0, 424.0), (196.0, 416.0)], [(200.0, 424.0), (195.0, 418.0)], [(203.0, 423.0), (195.0, 416.0)], [(257.0, 367.0), (198.0, 414.0)], [(200.0, 418.0), (199.0, 411.0)], [(257.0, 365.0), (200.0, 413.0)], [(256.0, 366.0), (199.0, 411.0)], [(198.0, 420.0), (197.0, 415.0)], [(257.0, 367.0), (196.0, 418.0)], [(256.0, 365.0), (195.0, 422.0)], [(256.0, 365.0), (195.0, 421.0)], [(197.0, 415.0), (196.0, 411.0)], [(196.0, 416.0), (196.0, 411.0)], [(198.0, 417.0), (197.0, 410.0)], [(198.0, 417.0), (197.0, 410.0)], [(258.0, 368.0), (196.0, 412.0)], [(248.0, 368.0), (197.0, 414.0)], [(204.0, 92.0), (204.0, 92.0)], [(197.0, 382.0), (233.0, 376.0)], [(236.0, 395.0), (202.0, 388.0)]]

# %% [markdown]
# ### Amount of Z-direction movement  &  Even right and left leg movements

# %% [markdown]
# #### Typical

# %%
left_min = 9999999
left_max = -9999999

right_min = 9999999
right_max = -9999999

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively
for ankles in Typical:
    
    left_ankle = ankles[0]
    left_x = left_ankle[0]
#     left_y = left_ankle[1]
    
    right_ankle = ankles[1]
    right_x = right_ankle[0]
#     right_y = right_ankle[1]
    
    
    if left_min > left_x:
        left_min = left_x
    
    if left_max < left_x:
        left_max = left_x

    if right_min > right_x:
        right_min = right_x
    
    if right_max < right_x:
        right_max = right_x
    

print(left_min)
print(left_max)
print(right_min)
print(right_max)
# Out:
# 102.0
# 234.0
# 28.0
# 233.0

# %% [markdown]
# #### Atypical

# %%
left_min = 9999999
left_max = -9999999

right_min = 9999999
right_max = -9999999

## ankles is a list of tuples --> [(x,y), (x,y)]   where the coordinates are left + right ankles respectively
for ankles in Atypical:
    
    left_ankle = ankles[0]
    left_x = left_ankle[0]
#     left_y = left_ankle[1]
    
    right_ankle = ankles[1]
    right_x = right_ankle[0]
#     right_y = right_ankle[1]
    
    
    if left_min > left_x:
        left_min = left_x
    
    if left_max < left_x:
        left_max = left_x

    if right_min > right_x:
        right_min = right_x
    
    if right_max < right_x:
        right_max = right_x
    

print(left_min)
print(left_max)
print(right_min)
print(right_max)
# Out:
# 196.0
# 258.0
# 195.0
# 233.0

# %% [markdown]
# ### Particular ranges of movement and averages considered "normal" for typical babies collected
# ### from real baby video dataset
#
# ### To understand where the line lies between "typical" and being an indicator
# ### for early cerebral palsy, the ranges of movement observed for atypical babies
# ### were contrasted against diagnosed "normal" babies using anomaly and outlier detection
